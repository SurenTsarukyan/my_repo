# %%
# Գեներացնել 1-ից 1_000_000 միջակայքում գտնվող կենտ թվերը
odd_numbers = list(range(1, 1_000_001, 2))

# %%
# Պահել դրանք data.pkl ֆայլում
import pickle
with open("data.pkl", "wb") as f:
    pickle.dump(odd_numbers, f)
